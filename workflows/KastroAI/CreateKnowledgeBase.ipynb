# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.insert(0, "../..")

# %%
from CommsIO import telegram
import jmespath

# %%
msg = telegram.trigger({
    "bot_token": "8539008369:AAEjVc5LdDaXFCbaPTadEUgn0kJffwzvoZ8",
    "include_existing": False,
    "timeout_seconds": 120
})
msg
# Out:
# {'update_id': 232715233,
#  'message_type': 'message',
#  'message_id': 237,
#  'date': 1771891537,
#  'text': 'Sup',
#  'chat': {'id': 1389414622,
#   'type': 'private',
#   'title': None,
#   'username': 'Fid_K',
#   'first_name': 'Fid',
#   'last_name': 'K'},
#  'sender': {'id': 1389414622,
#   'is_bot': False,
#   'username': 'Fid_K',
#   'first_name': 'Fid',
#   'last_name': 'K',
#   'language_code': 'en'},
#  'entities': [],
#  'raw': {'update_id': 232715233,
#   'message': {'message_id': 237,
#    'from': {'id': 1389414622,
#     'is_bot': False,
#     'first_name': 'Fid',
#     'last_name': 'K',
#     'username': 'Fid_K',
#     'language_code': 'en'},
#    'chat': {'id': 1389414622,
#     'first_name': 'Fid',
#     'last_name': 'K',
#     'username': 'Fid_K',
#     'type': 'private'},
#    'date': 1771891537,
#    'text': 'Sup'}}}

# %%
text = jmespath.search("text", msg)
text
# Out:
# 'Sup'
