# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
sys.path.insert(0, "../..")

# %%
from comms import telegram

# %%
msg = telegram.trigger({
    "bot_token": os.getenv("TELEGRAM_BOT_TOKEN"),
    "include_existing": False,
    "timeout_seconds": 120
})
msg
# Out:
# {'update_id': 232715237,
#  'message_type': 'message',
#  'message_id': 243,
#  'date': 1772324215,
#  'text': 'Sup',
#  'chat': {'id': 1389414622,
#   'type': 'private',
#   'title': None,
#   'username': 'Fid_K',
#   'first_name': 'Fid',
#   'last_name': 'K'},
#  'sender': {'id': 1389414622,
#   'is_bot': False,
#   'username': 'Fid_K',
#   'first_name': 'Fid',
#   'last_name': 'K',
#   'language_code': 'en'},
#  'entities': [],
#  'raw': {'update_id': 232715237,
#   'message': {'message_id': 243,
#    'from': {'id': 1389414622,
#     'is_bot': False,
#     'first_name': 'Fid',
#     'last_name': 'K',
#     'username': 'Fid_K',
#     'language_code': 'en'},
#    'chat': {'id': 1389414622,
#     'first_name': 'Fid',
#     'last_name': 'K',
#     'username': 'Fid_K',
#     'type': 'private'},
#    'date': 1772324215,
#    'text': 'Sup'}}}

# %%
text = msg["text"]
text
